# %%
import os
import pandas as pd
import shutil

# %%
os.chdir('/Users/anushasubramanian/Desktop/Research/UCLA/vcf')

# %%
ls
# Out:
# yi283_AATTGA.ATCGCGTTACGTCGT.vcf  yi297_AATTGA.CTTTCTCTTAGTCTA.vcf
# yi283_AATTGA.ATCGCGTTAGAACTA.vcf  yi297_AATTGA.CTTTCTCTTCGGTTT.vcf
# yi283_AATTGA.ATCGCGTTAGAGACT.vcf  yi297_AATTGA.GAGTCTTTCTGTTAA.vcf
# yi283_AATTGA.ATCGCGTTAGTAGCC.vcf  yi297_AATTGA.GAGTCTTTGACCTTC.vcf
# yi283_AATTGA.ATCGCGTTATCCGTA.vcf  yi297_AATTGA.GAGTCTTTGGGCGAG.vcf
# yi283_AATTGA.ATCGCGTTCAGAGGT.vcf  yi297_AATTGA.GAGTCTTTGGTCCCA.vcf
# yi283_AATTGA.ATCGCGTTGACCTTC.vcf  yi297_AATTGA.GAGTCTTTGTAATTT.vcf
# yi283_AATTGA.ATCGCGTTGGGCGAG.vcf  yi297_AATTGA.GAGTCTTTTCCATAG.vcf
# yi283_AATTGA.ATCGCGTTGGGTACA.vcf  yi297_AATTGA.GAGTCTTTTTACTTA.vcf
# yi283_AATTGA.ATCGCGTTGGTCCCA.vcf  yi297_AATTGA.GATCCCGTAGGTAGT.vcf
# yi283_AATTGA.ATCGCGTTGTGCCGC.vcf  yi297_AATTGA.GATCCCGTTAGCCGG.vcf
# yi283_AATTGA.ATCGCGTTTCACAGC.vcf  yi297_AATTGA.GATCCCGTTAGTCTA.vcf
# yi283_AATTGA.ATCGCGTTTCCAAGT.vcf  yi297_AATTGA.GATCCCGTTCCAAGT.vcf
# yi283_AATTGA.ATCGCGTTTCGAGTA.vcf  yi297_AATTGA.GATCCCGTTGATGCA.vcf
# ...

# %%
len(os.listdir())
# Out:
# 7704

# %%
for i in os.listdir():
    if i.find(".vcf") != -1:
        file = i[:i.find(".vcf")]
        shutil.copyfile('{0}.vcf'.format(file),'{0}.tsv'.format(file))
        shutil.move('{0}.tsv'.format(file), '/Users/anushasubramanian/Desktop/tsv')
